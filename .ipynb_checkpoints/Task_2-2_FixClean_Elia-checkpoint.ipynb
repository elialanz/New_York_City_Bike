# %% [markdown]
# ### Importing Libraries and Datasets

# %%
# Import Required Libraries

import pandas as pd
import numpy as np
import matplotlib
import os
from matplotlib import pyplot as plt
from datetime import datetime as dt

# %%
# Assigning Path

path = r'/Users/elia/Desktop/New_York_City_Bike'

# %%
# Import Merged CitiBike DataSet as a DataFrame

df = pd.read_csv(os.path.join(path, 'CB_Data', 'Prepared Data', 'ny_citybike.csv'))
# Out:
# /var/folders/kg/d6djty_168l6kzcc718bcldm0000gn/T/ipykernel_19497/1840826033.py:3: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, 'CB_Data', 'Prepared Data', 'ny_citybike.csv'))

# %% [markdown]
# ### Cleaning & Consistency Checks

# %%
# Identify columns in df dataframe that contain mixed data types

for col in df.columns.tolist():
  weird = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# start_station_name
# start_station_id
# end_station_name
# end_station_id

# %%
# Display the data type of each column in the dataframe

df.dtypes
# Out:
# Unnamed: 0              int64
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# tripduration          float64
# date                   object
# avgTemp               float64
# _merge                 object
# dtype: object

# %%
# Count missing values in each column of the dataframe

df.isnull().sum()
# Out:
# Unnamed: 0                0
# ride_id                   0
# rideable_type             0
# started_at                0
# ended_at                  0
# start_station_name       49
# start_station_id         49
# end_station_name      69884
# end_station_id        69884
# start_lat                 0
# start_lng                 0
# end_lat               37223
# end_lng               37223
# member_casual             0
# tripduration              0
# date                      0
# avgTemp                   0
# _merge                    0
# dtype: int64

# %% [markdown]
# ### Check "start_station_name" Column

# %%
# Inspect data types inside the 'start_station_name' column
col = 'start_station_name'

# Count how many values are of each Python type
type_counts = df[col].map(lambda x: type(x).__name__).value_counts(dropna=False)

# Total number of records in the column
total_count = len(df[col])

# Print column name, data type counts, and total number of records
print(f"Column: {col}")
print("\nCounts by Python type:")
print(type_counts)
print("\nTotal records:", total_count)
# Out:
# Column: start_station_name
#
# Counts by Python type:
# start_station_name
# str      29838117
# float          49
# Name: count, dtype: int64
#
# Total records: 29838166

# %%
# Specify which column to analyze for data type issues
col = "start_station_name"

# Identify all unique Python types inside the column
unique_types = df[col].map(type).unique()

# Loop through each detected data type, show sample rows, and count occurrences
for t in unique_types:
    print(f"\n=== Data type: {t.__name__} ===")
    subset = df[df[col].map(type) == t]
    display(subset.head(3))
    print(f"Total rows of this type: {len(subset)}")
# Out:
# === Data type: str ===
#    Unnamed: 0           ride_id  rideable_type               started_at  \
# 0           0  9D0DC440CB40CF8E  electric_bike  2022-08-27 13:56:47.728
# 1           1  2214991DFBE5C4D7  electric_bike  2022-08-20 10:37:02.756
# 2           2  20C5D469563B6337   classic_bike  2022-08-31 18:55:03.051
#
#                   ended_at        start_station_name start_station_id  \
# 0  2022-08-27 14:02:56.651  Flatbush Ave & Ocean Ave          3704.04
# 1  2022-08-20 10:45:56.631    Forsyth St\t& Grand St          5382.07
# 2  2022-08-31 19:03:37.344    Perry St & Bleecker St          5922.07
#
#             end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0  3 St & Prospect Park West        3865.05  40.663657 -73.963014  40.668132
# 1            E 11 St & 1 Ave        5746.14  40.717798 -73.993161  40.729538
# 2       Grand St & Greene St        5500.02  40.735354 -74.004831  40.721700
#
# ...

# %%
# Remove rows where 'start_station_name' is not a string
df_clean = df[df['start_station_name'].map(type) == str].copy()

# Optional: check how many rows were removed
removed = len(df) - len(df_clean)
print("Rows removed:", removed)
print("New total rows:", len(df_clean))
# Out:
# Rows removed: 49
# New total rows: 29838117

# %% [markdown]
# ### Check "start_station_id" Column

# %%
# Inspect data types inside the 'start_station_name' column
col = 'start_station_id'

# Count how many values are of each Python type
type_counts = df[col].map(lambda x: type(x).__name__).value_counts(dropna=False)

# Total number of records in the column
total_count = len(df[col])

# Print column name, data type counts, and total number of records
print(f"Column: {col}")
print("\nCounts by Python type:")
print(type_counts)
print("\nTotal records:", total_count)
# Out:
# Column: start_station_id
#
# Counts by Python type:
# start_station_id
# float    22727517
# str       7110649
# Name: count, dtype: int64
#
# Total records: 29838166

# %%
# Specify which column to analyze for data type issues
col = "start_station_id"

# Identify all unique Python types inside the column
unique_types = df[col].map(type).unique()

# Loop through each detected data type, show sample rows, and count occurrences
for t in unique_types:
    print(f"\n=== Data type: {t.__name__} ===")
    subset = df[df[col].map(type) == t]
    display(subset.head(25))
    print(f"Total rows of this type: {len(subset)}")
# Out:
# === Data type: float ===
#     Unnamed: 0           ride_id  rideable_type               started_at  \
# 0            0  9D0DC440CB40CF8E  electric_bike  2022-08-27 13:56:47.728
# 1            1  2214991DFBE5C4D7  electric_bike  2022-08-20 10:37:02.756
# 2            2  20C5D469563B6337   classic_bike  2022-08-31 18:55:03.051
# 3            3  3E8791885BC189D1   classic_bike  2022-08-02 08:05:00.250
# 4            4  8DBCBF98885106CB  electric_bike  2022-08-25 15:44:48.386
# 5            5  CAB096D575EDC132   classic_bike  2022-08-24 13:02:54.342
# 6            6  EF8544B5A2DCF0DD   classic_bike  2022-08-15 19:55:31.144
# 7            7  2654CA1F2EC82B02  electric_bike  2022-08-16 14:18:55.470
# 8            8  6E6D64F513638A18  electric_bike  2022-08-31 13:04:05.710
# 9            9  C02596B5564610A7   classic_bike  2022-08-28 12:33:53.619
# 10          10  6E5DD5470F153ADB   classic_bike  2022-08-06 10:47:03.156
# ...

# %%
# Specify which column to analyze for data type issues
col = "start_station_id"

# Identify all unique Python types inside the column
unique_types = df[col].map(type).unique()

# Loop through each detected data type, show sample rows, and count occurrences
for t in unique_types:
    print(f"\n=== Data type: {t.__name__} ===")
    subset = df[df[col].map(type) == t]
    display(subset.tail(25))
    print(f"Total rows of this type: {len(subset)}")
# Out:
# === Data type: float ===
#           Unnamed: 0           ride_id  rideable_type  \
# 29838141    29838141  D9EB89B1A590544F  electric_bike
# 29838142    29838142  5139D95B46F7AC3B  electric_bike
# 29838143    29838143  26D76CA8EAFB2923  electric_bike
# 29838144    29838144  3BDB3203F3523EFE  electric_bike
# 29838145    29838145  1294C444F7BC122D   classic_bike
# 29838146    29838146  C4D7FDDA76CBFCB5  electric_bike
# 29838147    29838147  8466720FD32C3674   classic_bike
# 29838148    29838148  D7CEFBB707E089D2  electric_bike
# 29838149    29838149  3F0898A7F0142F1B  electric_bike
# 29838150    29838150  F15549755283C5A2  electric_bike
# 29838151    29838151  D8CD6479A4910A69   classic_bike
# 29838152    29838152  6EA1B8D81EBD9EEF   classic_bike
# 29838153    29838153  9C728D3FE3D1F16F  electric_bike
# 29838154    29838154  DD929CC6766679E7   classic_bike
# 29838155    29838155  290C5B0285780DBC  electric_bike
# 29838156    29838156  8EA1816EE0DDCDF0  electric_bike
# ...

# %%
# Remove rows where start_station_id is missing

df_clean_01 = df_clean[df_clean['start_station_id'].notna()].copy()

# %%
df_clean.shape
# Out:
# (29838117, 18)

# %%
df_clean_01.shape
# Out:
# (29838117, 18)

# %%
# Optional: check how many rows were removed

removed = len(df) - len(df_clean_01)
print("Rows removed:", removed)
print("New total rows:", len(df_clean_01))
# Out:
# Rows removed: 49
# New total rows: 29838117

# %%
# Optional: check how many rows were removed

removed = len(df_clean) - len(df_clean_01)
print("Rows removed:", removed)
print("New total rows:", len(df_clean_01))
# Out:
# Rows removed: 0
# New total rows: 29838117

# %%
df_clean_01['start_station_id'] = df_clean_01['start_station_id'].astype(str)

# %%
# Check Python types inside the column after conversion

print(df_clean_01['start_station_id'].map(type).value_counts())
# Out:
# start_station_id
# <class 'str'>    29838117
# Name: count, dtype: int64

# %% [markdown]
# ### Check "end_station_name" Column

# %%
# Inspect data types inside the 'end_station_name' column
col = 'end_station_name'

# Count how many values are of each Python type
type_counts = df_clean_01[col].map(lambda x: type(x).__name__).value_counts(dropna=False)

# Total number of records in the column
total_count = len(df_clean_01[col])

# Print column name, data type counts, and total number of records
print(f"Column: {col}")
print("\nCounts by Python type:")
print(type_counts)
print("\nTotal records:", total_count)
# Out:
# Column: end_station_name
#
# Counts by Python type:
# end_station_name
# str      29768282
# float       69835
# Name: count, dtype: int64
#
# Total records: 29838117

# %%
# Specify which column to analyze for data type issues
col = "end_station_name"

# Identify all unique Python types inside the column
unique_types = df_clean_01[col].map(type).unique()

# Loop through each detected data type, show sample rows, and count occurrences
for t in unique_types:
    print(f"\n=== Data type: {t.__name__} ===")
    subset = df_clean_01[df_clean_01[col].map(type) == t]
    display(subset.head(25))
    print(f"Total rows of this type: {len(subset)}")
# Out:
# === Data type: str ===
#     Unnamed: 0           ride_id  rideable_type               started_at  \
# 0            0  9D0DC440CB40CF8E  electric_bike  2022-08-27 13:56:47.728
# 1            1  2214991DFBE5C4D7  electric_bike  2022-08-20 10:37:02.756
# 2            2  20C5D469563B6337   classic_bike  2022-08-31 18:55:03.051
# 3            3  3E8791885BC189D1   classic_bike  2022-08-02 08:05:00.250
# 4            4  8DBCBF98885106CB  electric_bike  2022-08-25 15:44:48.386
# 5            5  CAB096D575EDC132   classic_bike  2022-08-24 13:02:54.342
# 6            6  EF8544B5A2DCF0DD   classic_bike  2022-08-15 19:55:31.144
# 7            7  2654CA1F2EC82B02  electric_bike  2022-08-16 14:18:55.470
# 8            8  6E6D64F513638A18  electric_bike  2022-08-31 13:04:05.710
# 9            9  C02596B5564610A7   classic_bike  2022-08-28 12:33:53.619
# 10          10  6E5DD5470F153ADB   classic_bike  2022-08-06 10:47:03.156
# ...

# %%
# Specify which column to analyze for data type issues
col = "end_station_name"

# Identify all unique Python types inside the column
unique_types = df_clean_01[col].map(type).unique()

# Loop through each detected data type, show sample rows, and count occurrences
for t in unique_types:
    print(f"\n=== Data type: {t.__name__} ===")
    subset = df_clean_01[df_clean_01[col].map(type) == t]
    display(subset.tail(25))
    print(f"Total rows of this type: {len(subset)}")
# Out:
# === Data type: str ===
#           Unnamed: 0           ride_id  rideable_type  \
# 29838141    29838141  D9EB89B1A590544F  electric_bike
# 29838142    29838142  5139D95B46F7AC3B  electric_bike
# 29838143    29838143  26D76CA8EAFB2923  electric_bike
# 29838144    29838144  3BDB3203F3523EFE  electric_bike
# 29838145    29838145  1294C444F7BC122D   classic_bike
# 29838146    29838146  C4D7FDDA76CBFCB5  electric_bike
# 29838147    29838147  8466720FD32C3674   classic_bike
# 29838148    29838148  D7CEFBB707E089D2  electric_bike
# 29838149    29838149  3F0898A7F0142F1B  electric_bike
# 29838150    29838150  F15549755283C5A2  electric_bike
# 29838151    29838151  D8CD6479A4910A69   classic_bike
# 29838152    29838152  6EA1B8D81EBD9EEF   classic_bike
# 29838153    29838153  9C728D3FE3D1F16F  electric_bike
# 29838154    29838154  DD929CC6766679E7   classic_bike
# 29838155    29838155  290C5B0285780DBC  electric_bike
# 29838156    29838156  8EA1816EE0DDCDF0  electric_bike
# ...

# %%
# How many rows have missing end_station_name?

missing_end_name = df_clean_01['end_station_name'].isna().sum()
print("Rows with missing end_station_name:", missing_end_name)
# Out:
# Rows with missing end_station_name: 69835

# %%
# 2. Drop those rows

df_clean_02 = df_clean_01[~df_clean_01['end_station_name'].isna()].copy()
print("Rows after dropping:", len(df_clean_02))
# Out:
# Rows after dropping: 29768282

# %% [markdown]
# #### The "end_station_name" column contained 69,884 rows where the value was missing (NaN), and some of these rows also had missing end station coordinates.
# #### Since this represents only about 0.23% of the full dataset and the rides cannot be used for station level analysis, I removed these incomplete rows.
# #### After that, I converted the "end_station_name" column to string to keep the data type consistent.

# %% [markdown]
# #### -----------

# %% [markdown]
# ### Check "end_station_id" Column

# %%
# Inspect data types inside the 'end_station_id' column
col = 'end_station_id'

# Count how many values are of each Python type
type_counts = df_clean_02[col].map(lambda x: type(x).__name__).value_counts(dropna=False)

# Total number of records in the column
total_count = len(df_clean_02[col])

# Print column name, data type counts, and total number of records
print(f"Column: {col}")
print("\nCounts by Python type:")
print(type_counts)
print("\nTotal records:", total_count)
# Out:
# Column: end_station_id
#
# Counts by Python type:
# end_station_id
# str      15337135
# float    14431147
# Name: count, dtype: int64
#
# Total records: 29768282

# %%
# Specify which column to analyze for data type issues
col = "end_station_id"

# Identify all unique Python types inside the column
unique_types = df_clean_02[col].map(type).unique()

# Loop through each detected data type, show sample rows, and count occurrences
for t in unique_types:
    print(f"\n=== Data type: {t.__name__} ===")
    subset = df_clean_02[df_clean_02[col].map(type) == t]
    display(subset.head(25))
    print(f"Total rows of this type: {len(subset)}")
# Out:
# === Data type: float ===
#     Unnamed: 0           ride_id  rideable_type               started_at  \
# 0            0  9D0DC440CB40CF8E  electric_bike  2022-08-27 13:56:47.728
# 1            1  2214991DFBE5C4D7  electric_bike  2022-08-20 10:37:02.756
# 2            2  20C5D469563B6337   classic_bike  2022-08-31 18:55:03.051
# 3            3  3E8791885BC189D1   classic_bike  2022-08-02 08:05:00.250
# 4            4  8DBCBF98885106CB  electric_bike  2022-08-25 15:44:48.386
# 5            5  CAB096D575EDC132   classic_bike  2022-08-24 13:02:54.342
# 6            6  EF8544B5A2DCF0DD   classic_bike  2022-08-15 19:55:31.144
# 7            7  2654CA1F2EC82B02  electric_bike  2022-08-16 14:18:55.470
# 8            8  6E6D64F513638A18  electric_bike  2022-08-31 13:04:05.710
# 9            9  C02596B5564610A7   classic_bike  2022-08-28 12:33:53.619
# 10          10  6E5DD5470F153ADB   classic_bike  2022-08-06 10:47:03.156
# ...

# %%
# Specify which column to analyze for data type issues
col = "end_station_id"

# Identify all unique Python types inside the column
unique_types = df_clean_02[col].map(type).unique()

# Loop through each detected data type, show sample rows, and count occurrences
for t in unique_types:
    print(f"\n=== Data type: {t.__name__} ===")
    subset = df_clean_02[df_clean_02[col].map(type) == t]
    display(subset.tail(25))
    print(f"Total rows of this type: {len(subset)}")
# Out:
# === Data type: float ===
#           Unnamed: 0           ride_id  rideable_type  \
# 29838141    29838141  D9EB89B1A590544F  electric_bike
# 29838142    29838142  5139D95B46F7AC3B  electric_bike
# 29838143    29838143  26D76CA8EAFB2923  electric_bike
# 29838144    29838144  3BDB3203F3523EFE  electric_bike
# 29838145    29838145  1294C444F7BC122D   classic_bike
# 29838146    29838146  C4D7FDDA76CBFCB5  electric_bike
# 29838147    29838147  8466720FD32C3674   classic_bike
# 29838148    29838148  D7CEFBB707E089D2  electric_bike
# 29838149    29838149  3F0898A7F0142F1B  electric_bike
# 29838150    29838150  F15549755283C5A2  electric_bike
# 29838151    29838151  D8CD6479A4910A69   classic_bike
# 29838152    29838152  6EA1B8D81EBD9EEF   classic_bike
# 29838153    29838153  9C728D3FE3D1F16F  electric_bike
# 29838154    29838154  DD929CC6766679E7   classic_bike
# 29838155    29838155  290C5B0285780DBC  electric_bike
# 29838156    29838156  8EA1816EE0DDCDF0  electric_bike
# ...

# %%
# Count missing values in each column of the dataframe

df_clean_02.isnull().sum()
# Out:
# Unnamed: 0            0
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# tripduration          0
# date                  0
# avgTemp               0
# _merge                0
# dtype: int64

# %%
# Identify columns in df dataframe that contain mixed data types

for col in df_clean_02.columns.tolist():
  weird = (df_clean_02[[col]].map(type) != df_clean_02[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_clean_02[weird]) > 0:
    print (col)
# Out:
# end_station_id

# %%
df_clean_02['end_station_id'] = df_clean_02['end_station_id'].astype(str)

# %%
# Inspect data types inside the 'end_station_id' column
col = 'end_station_id'

# Count how many values are of each Python type
type_counts = df_clean_02[col].map(lambda x: type(x).__name__).value_counts(dropna=False)

# Total number of records in the column
total_count = len(df_clean_02[col])

# Print column name, data type counts, and total number of records
print(f"Column: {col}")
print("\nCounts by Python type:")
print(type_counts)
print("\nTotal records:", total_count)
# Out:
# Column: end_station_id
#
# Counts by Python type:
# end_station_id
# str    29768282
# Name: count, dtype: int64
#
# Total records: 29768282

# %%
df.shape
# Out:
# (29838166, 18)

# %%
df_clean_02.shape
# Out:
# (29768282, 18)

# %%
29838166 - 29768282
# Out:
# 69884

# %%
# Count missing values in each column of the dataframe

df.isnull().sum()
# Out:
# Unnamed: 0                0
# ride_id                   0
# rideable_type             0
# started_at                0
# ended_at                  0
# start_station_name       49
# start_station_id         49
# end_station_name      69884
# end_station_id        69884
# start_lat                 0
# start_lng                 0
# end_lat               37223
# end_lng               37223
# member_casual             0
# tripduration              0
# date                      0
# avgTemp                   0
# _merge                    0
# dtype: int64

# %%
# Count missing values in each column of the dataframe

df_clean_02.isnull().sum()
# Out:
# Unnamed: 0            0
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# tripduration          0
# date                  0
# avgTemp               0
# _merge                0
# dtype: int64

# %%
# Identify columns in df dataframe that contain mixed data types

for col in df.columns.tolist():
  weird = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# start_station_name
# start_station_id
# end_station_name
# end_station_id

# %%
# Identify columns in df_clean_02 dataframe that contain mixed data types

for col in df_clean_02.columns.tolist():
  weird = (df_clean_02[[col]].map(type) != df_clean_02[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_clean_02[weird]) > 0:
    print (col)

# %%
# Export Cleaned DataFrame to Csv

df_clean_02.to_csv(os.path.join(path, 'CB_Data', 'Prepared Data', 'ny_citybike.csv'))
